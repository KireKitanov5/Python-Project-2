# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.read_csv('Desktop/bitcoin_price_Training - Training.csv')
# Out:
#               Date     Open     High      Low    Close         Volume  \
# 0     Jul 31, 2017  2763.24  2889.62  2720.61  2875.34    860,575,000
# 1     Jul 30, 2017  2724.39  2758.53  2644.85  2757.18    705,943,000
# 2     Jul 29, 2017  2807.02  2808.76  2692.80  2726.45    803,746,000
# 3     Jul 28, 2017  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 4     Jul 27, 2017  2538.71  2693.32  2529.34  2671.78    789,104,000
# ...            ...      ...      ...      ...      ...            ...
# 1551  May 02, 2013   116.38   125.60    92.28   105.21              -
# 1552  May 01, 2013   139.00   139.89   107.72   116.99              -
# 1553  Apr 30, 2013   144.00   146.93   134.05   139.00              -
# 1554  Apr 29, 2013   134.44   147.49   134.00   144.54              -
# 1555  Apr 28, 2013   135.30   135.98   132.10   134.21              -
#
#           Market Cap
# 0     45,535,800,000
# 1     44,890,700,000
# 2     46,246,700,000
# 3     44,144,400,000
# ...

# %%
df=pd.read_csv('Desktop/bitcoin_price_Training - Training.csv')

# %%
df.head()
# Out:
#            Date     Open     High      Low    Close         Volume  \
# 0  Jul 31, 2017  2763.24  2889.62  2720.61  2875.34    860,575,000
# 1  Jul 30, 2017  2724.39  2758.53  2644.85  2757.18    705,943,000
# 2  Jul 29, 2017  2807.02  2808.76  2692.80  2726.45    803,746,000
# 3  Jul 28, 2017  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 4  Jul 27, 2017  2538.71  2693.32  2529.34  2671.78    789,104,000
#
#        Market Cap
# 0  45,535,800,000
# 1  44,890,700,000
# 2  46,246,700,000
# 3  44,144,400,000
# 4  41,816,500,000

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
df.shape
# Out:
# (1556, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1556 entries, 0 to 1555
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        1556 non-null   object
#  1   Open        1556 non-null   float64
#  2   High        1556 non-null   float64
#  3   Low         1556 non-null   float64
#  4   Close       1556 non-null   float64
#  5   Volume      1556 non-null   object
#  6   Market Cap  1556 non-null   object
# dtypes: float64(4), object(3)
# memory usage: 85.2+ KB

# %%
df.describe()
# Out:
#               Open         High          Low        Close
# count  1556.000000  1556.000000  1556.000000  1556.000000
# mean    582.625328   597.992847   567.851446   584.239396
# std     523.137312   542.992855   505.877401   525.904442
# min      68.500000    74.560000    65.530000    68.430000
# 25%     254.287500   260.327500   248.835000   254.320000
# 50%     438.600000   447.560000   430.570000   438.855000
# 75%     662.437500   674.525000   646.735000   663.402500
# max    2953.220000  2999.910000  2840.530000  2958.110000

# %%
df.describe().T
# Out:
#         count        mean         std    min       25%      50%       75%  \
# Open   1556.0  582.625328  523.137312  68.50  254.2875  438.600  662.4375
# High   1556.0  597.992847  542.992855  74.56  260.3275  447.560  674.5250
# Low    1556.0  567.851446  505.877401  65.53  248.8350  430.570  646.7350
# Close  1556.0  584.239396  525.904442  68.43  254.3200  438.855  663.4025
#
#            max
# Open   2953.22
# High   2999.91
# Low    2840.53
# Close  2958.11

# %% [markdown]
# #Data Pre-processing

# %%
df.dtypes
# Out:
# Date           object
# Open          float64
# High          float64
# Low           float64
# Close         float64
# Volume         object
# Market Cap     object
# dtype: object

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
#df['Date'].astype('datetime64[ns]')

# %%
df['Date'].min()
# Out:
# Timestamp('2013-04-28 00:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2017-07-31 00:00:00')

# %%
type(df['Date'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.isnull().sum()
# Out:
# Date          0
# Open          0
# High          0
# Low           0
# Close         0
# Volume        0
# Market Cap    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.head(3)
# Out:
#         Date     Open     High      Low    Close       Volume      Market Cap
# 0 2017-07-31  2763.24  2889.62  2720.61  2875.34  860,575,000  45,535,800,000
# 1 2017-07-30  2724.39  2758.53  2644.85  2757.18  705,943,000  44,890,700,000
# 2 2017-07-29  2807.02  2808.76  2692.80  2726.45  803,746,000  46,246,700,000

# %%
df.tail()
# Out:
#            Date    Open    High     Low   Close Volume     Market Cap
# 1551 2013-05-02  116.38  125.60   92.28  105.21      -  1,292,190,000
# 1552 2013-05-01  139.00  139.89  107.72  116.99      -  1,542,820,000
# 1553 2013-04-30  144.00  146.93  134.05  139.00      -  1,597,780,000
# 1554 2013-04-29  134.44  147.49  134.00  144.54      -  1,491,160,000
# 1555 2013-04-28  135.30  135.98  132.10  134.21      -  1,500,520,000

# %%
df.sort_index()
# Out:
#            Date     Open     High      Low    Close         Volume  \
# 0    2017-07-31  2763.24  2889.62  2720.61  2875.34    860,575,000
# 1    2017-07-30  2724.39  2758.53  2644.85  2757.18    705,943,000
# 2    2017-07-29  2807.02  2808.76  2692.80  2726.45    803,746,000
# 3    2017-07-28  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 4    2017-07-27  2538.71  2693.32  2529.34  2671.78    789,104,000
# ...         ...      ...      ...      ...      ...            ...
# 1551 2013-05-02   116.38   125.60    92.28   105.21              -
# 1552 2013-05-01   139.00   139.89   107.72   116.99              -
# 1553 2013-04-30   144.00   146.93   134.05   139.00              -
# 1554 2013-04-29   134.44   147.49   134.00   144.54              -
# 1555 2013-04-28   135.30   135.98   132.10   134.21              -
#
#           Market Cap
# 0     45,535,800,000
# 1     44,890,700,000
# 2     46,246,700,000
# 3     44,144,400,000
# 4     41,816,500,000
# ...              ...
# ...

# %%
df.sort_index(ascending=False)
# Out:
#            Date     Open     High      Low    Close         Volume  \
# 1555 2013-04-28   135.30   135.98   132.10   134.21              -
# 1554 2013-04-29   134.44   147.49   134.00   144.54              -
# 1553 2013-04-30   144.00   146.93   134.05   139.00              -
# 1552 2013-05-01   139.00   139.89   107.72   116.99              -
# 1551 2013-05-02   116.38   125.60    92.28   105.21              -
# ...         ...      ...      ...      ...      ...            ...
# 4    2017-07-27  2538.71  2693.32  2529.34  2671.78    789,104,000
# 3    2017-07-28  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 2    2017-07-29  2807.02  2808.76  2692.80  2726.45    803,746,000
# 1    2017-07-30  2724.39  2758.53  2644.85  2757.18    705,943,000
# 0    2017-07-31  2763.24  2889.62  2720.61  2875.34    860,575,000
#
#           Market Cap
# 1555   1,500,520,000
# 1554   1,491,160,000
# 1553   1,597,780,000
# 1552   1,542,820,000
# 1551   1,292,190,000
# ...              ...
# ...

# %% [markdown]
# #Analysing change in price of Bitcoin over time

# %%
data = df.sort_index(ascending=False).reset_index()

# %%
data
# Out:
#       index       Date     Open     High      Low    Close         Volume  \
# 0      1555 2013-04-28   135.30   135.98   132.10   134.21              -
# 1      1554 2013-04-29   134.44   147.49   134.00   144.54              -
# 2      1553 2013-04-30   144.00   146.93   134.05   139.00              -
# 3      1552 2013-05-01   139.00   139.89   107.72   116.99              -
# 4      1551 2013-05-02   116.38   125.60    92.28   105.21              -
# ...     ...        ...      ...      ...      ...      ...            ...
# 1551      4 2017-07-27  2538.71  2693.32  2529.34  2671.78    789,104,000
# 1552      3 2017-07-28  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 1553      2 2017-07-29  2807.02  2808.76  2692.80  2726.45    803,746,000
# 1554      1 2017-07-30  2724.39  2758.53  2644.85  2757.18    705,943,000
# 1555      0 2017-07-31  2763.24  2889.62  2720.61  2875.34    860,575,000
#
#           Market Cap
# 0      1,500,520,000
# 1      1,491,160,000
# ...

# %%
data.drop('index',axis=1)
# Out:
#            Date     Open     High      Low    Close         Volume  \
# 0    2013-04-28   135.30   135.98   132.10   134.21              -
# 1    2013-04-29   134.44   147.49   134.00   144.54              -
# 2    2013-04-30   144.00   146.93   134.05   139.00              -
# 3    2013-05-01   139.00   139.89   107.72   116.99              -
# 4    2013-05-02   116.38   125.60    92.28   105.21              -
# ...         ...      ...      ...      ...      ...            ...
# 1551 2017-07-27  2538.71  2693.32  2529.34  2671.78    789,104,000
# 1552 2017-07-28  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 1553 2017-07-29  2807.02  2808.76  2692.80  2726.45    803,746,000
# 1554 2017-07-30  2724.39  2758.53  2644.85  2757.18    705,943,000
# 1555 2017-07-31  2763.24  2889.62  2720.61  2875.34    860,575,000
#
#           Market Cap
# 0      1,500,520,000
# 1      1,491,160,000
# 2      1,597,780,000
# 3      1,542,820,000
# 4      1,292,190,000
# ...              ...
# ...

# %%
data.drop('index',axis=1, inplace =True)

# %%
data
# Out:
#            Date     Open     High      Low    Close         Volume  \
# 0    2013-04-28   135.30   135.98   132.10   134.21              -
# 1    2013-04-29   134.44   147.49   134.00   144.54              -
# 2    2013-04-30   144.00   146.93   134.05   139.00              -
# 3    2013-05-01   139.00   139.89   107.72   116.99              -
# 4    2013-05-02   116.38   125.60    92.28   105.21              -
# ...         ...      ...      ...      ...      ...            ...
# 1551 2017-07-27  2538.71  2693.32  2529.34  2671.78    789,104,000
# 1552 2017-07-28  2679.73  2897.45  2679.73  2809.01  1,380,100,000
# 1553 2017-07-29  2807.02  2808.76  2692.80  2726.45    803,746,000
# 1554 2017-07-30  2724.39  2758.53  2644.85  2757.18    705,943,000
# 1555 2017-07-31  2763.24  2889.62  2720.61  2875.34    860,575,000
#
#           Market Cap
# 0      1,500,520,000
# 1      1,491,160,000
# 2      1,597,780,000
# 3      1,542,820,000
# 4      1,292,190,000
# ...              ...
# ...

# %%
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'Market Cap'], dtype='object')

# %%
for index, col in enumerate(['Open', 'High', 'Low', 'Close'],1):
    plt.subplot(2,2,index)
    plt.plot(df['Date'],df[col])
    plt.title(col)

# %%
plt.figure(figsize=(20,12))
for index, col in enumerate(['Open', 'High', 'Low', 'Close'],1):
    plt.subplot(2,2,index)
    plt.plot(df['Date'],df[col])
    plt.title(col)

# %% [markdown]
# #Analysing Open,Close,High,Low value of Bitcoin Prices using Candle-stick chart

# %%
data.shape
# Out:
# (1556, 7)

# %%
bitcoin_sample = data[0:50]

# %%
pip install install chart_studio
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go

# %%
import plotly.express as px
from plotly.offline import download_plotlyjs,init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
trace = go.Candlestick(x=bitcoin_sample['Date'],
                       high = bitcoin_sample['High'],
                       open = bitcoin_sample['Open'],
                       close = bitcoin_sample['Close'],
                       low = bitcoin_sample['Low'])

# %%
candle_data=[trace]

# %%
go.Figure(data=candle_data)
# Out:
# <div>                            <div id="8ca885e4-beee-44dd-812d-7113e6e0bef7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ca885e4-beee-44dd-812d-7113e6e0bef7")) {                    Plotly.newPlot(                        "8ca885e4-beee-44dd-812d-7113e6e0bef7",                        [{"close":[134.21,144.54,139.0,116.99,105.21,97.75,112.5,115.91,112.3,111.5,113.57,112.67,117.2,115.24,115.0,117.98,111.5,114.22,118.76,123.02,123.5,121.99,122.0,122.88,123.89,126.7,133.2,131.98,133.48,129.75,129.0,132.3,128.8,129.0,129.3,122.29,122.22,121.42,121.65,118.0,111.5,108.3,100.0,106.35,108.9,108.15,104.0,99.98,99.99,99.51],"high":[135.98,147.49,146.93,139.89,125.6,108.13,115.0,118.8,124.66,113.44,115.78,113.46,122.0,118.68,117.45,118.7,119.8,115.81,118.
# ...

# %%
candle_data = [trace]

layout = {'title':'Bitcoin Historical Price',
         'xaxis':{'title':'Date'}
         }

# %%
fig = go.Figure(data=candle_data,layout=layout)

fig.update_layout(xaxis_rangeslider_visible=False)

fig.show()
# Out:
# <div>                            <div id="7cdb21b3-988c-40d9-bbda-ebe231370c38" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7cdb21b3-988c-40d9-bbda-ebe231370c38")) {                    Plotly.newPlot(                        "7cdb21b3-988c-40d9-bbda-ebe231370c38",                        [{"close":[134.21,144.54,139.0,116.99,105.21,97.75,112.5,115.91,112.3,111.5,113.57,112.67,117.2,115.24,115.0,117.98,111.5,114.22,118.76,123.02,123.5,121.99,122.0,122.88,123.89,126.7,133.2,131.98,133.48,129.75,129.0,132.3,128.8,129.0,129.3,122.29,122.22,121.42,121.65,118.0,111.5,108.3,100.0,106.35,108.9,108.15,104.0,99.98,99.99,99.51],"high":[135.98,147.49,146.93,139.89,125.6,108.13,115.0,118.8,124.66,113.44,115.78,113.46,122.0,118.68,117.45,118.7,119.8,115.81,118.
# ...

# %% [markdown]
# Analysing Closing Price

# %%
data['Close']
# Out:
# 0        134.21
# 1        144.54
# 2        139.00
# 3        116.99
# 4        105.21
#          ...
# 1551    2671.78
# 1552    2809.01
# 1553    2726.45
# 1554    2757.18
# 1555    2875.34
# Name: Close, Length: 1556, dtype: float64

# %%
data['Close'].plot()
# Out:
# <AxesSubplot:>

# %%
data.set_index('Date')
# Out:
#                Open     High      Low    Close         Volume      Market Cap
# Date
# 2013-04-28   135.30   135.98   132.10   134.21              -   1,500,520,000
# 2013-04-29   134.44   147.49   134.00   144.54              -   1,491,160,000
# 2013-04-30   144.00   146.93   134.05   139.00              -   1,597,780,000
# 2013-05-01   139.00   139.89   107.72   116.99              -   1,542,820,000
# 2013-05-02   116.38   125.60    92.28   105.21              -   1,292,190,000
# ...             ...      ...      ...      ...            ...             ...
# 2017-07-27  2538.71  2693.32  2529.34  2671.78    789,104,000  41,816,500,000
# 2017-07-28  2679.73  2897.45  2679.73  2809.01  1,380,100,000  44,144,400,000
# 2017-07-29  2807.02  2808.76  2692.80  2726.45    803,746,000  46,246,700,000
# 2017-07-30  2724.39  2758.53  2644.85  2757.18    705,943,000  44,890,700,000
# 2017-07-31  2763.24  2889.62  2720.61  2875.34    860,575,000  45,535,800,000
#
# [1556 rows x 6 columns]

# %%
data.set_index('Date', inplace=True)

# %%
data
# Out:
#                Open     High      Low    Close         Volume      Market Cap
# Date
# 2013-04-28   135.30   135.98   132.10   134.21              -   1,500,520,000
# 2013-04-29   134.44   147.49   134.00   144.54              -   1,491,160,000
# 2013-04-30   144.00   146.93   134.05   139.00              -   1,597,780,000
# 2013-05-01   139.00   139.89   107.72   116.99              -   1,542,820,000
# 2013-05-02   116.38   125.60    92.28   105.21              -   1,292,190,000
# ...             ...      ...      ...      ...            ...             ...
# 2017-07-27  2538.71  2693.32  2529.34  2671.78    789,104,000  41,816,500,000
# 2017-07-28  2679.73  2897.45  2679.73  2809.01  1,380,100,000  44,144,400,000
# 2017-07-29  2807.02  2808.76  2692.80  2726.45    803,746,000  46,246,700,000
# 2017-07-30  2724.39  2758.53  2644.85  2757.18    705,943,000  44,890,700,000
# 2017-07-31  2763.24  2889.62  2720.61  2875.34    860,575,000  45,535,800,000
#
# [1556 rows x 6 columns]

# %%
plt.figure(figsize=(10,5))
data['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
np.log1p(data['Close'])
# Out:
# Date
# 2013-04-28    4.906829
# 2013-04-29    4.980451
# 2013-04-30    4.941642
# 2013-05-01    4.770600
# 2013-05-02    4.665418
#                 ...
# 2017-07-27    7.890874
# 2017-07-28    7.940943
# 2017-07-29    7.911122
# 2017-07-30    7.922326
# 2017-07-31    7.964274
# Name: Close, Length: 1556, dtype: float64

# %%
plt.figure(figsize=(10,5))
np.log1p(data['Close']).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
data['Close'].plot()

plt.subplot(1,2,2)
np.log1p(data['Close']).plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.figure(figsize=(20,8))

plt.subplot(1,2,1)
data['Close'].plot()
plt.title('No Scaling')

plt.subplot(1,2,2)
np.log1p(data['Close']).plot()
plt.title('Log Scaling')
plt.yscale('log')

# %% [markdown]
# Performing Analysis on Closing Price on Yearly, Quarterly & Monthly Basis

# %%
data.head()
# Out:
#               Open    High     Low   Close Volume     Market Cap
# Date
# 2013-04-28  135.30  135.98  132.10  134.21      -  1,500,520,000
# 2013-04-29  134.44  147.49  134.00  144.54      -  1,491,160,000
# 2013-04-30  144.00  146.93  134.05  139.00      -  1,597,780,000
# 2013-05-01  139.00  139.89  107.72  116.99      -  1,542,820,000
# 2013-05-02  116.38  125.60   92.28  105.21      -  1,292,190,000

# %%
data['Close']
# Out:
# Date
# 2013-04-28     134.21
# 2013-04-29     144.54
# 2013-04-30     139.00
# 2013-05-01     116.99
# 2013-05-02     105.21
#                ...
# 2017-07-27    2671.78
# 2017-07-28    2809.01
# 2017-07-29    2726.45
# 2017-07-30    2757.18
# 2017-07-31    2875.34
# Name: Close, Length: 1556, dtype: float64

# %% [markdown]
# Yearly Mean

# %%
data['Close'].resample('Y').mean()
# Out:
# Date
# 2013-12-31     257.474476
# 2014-12-31     527.236658
# 2015-12-31     272.453260
# 2016-12-31     568.492131
# 2017-12-31    1628.622123
# Freq: A-DEC, Name: Close, dtype: float64

# %%
data['Close'].resample('Y').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Quarterly Mean

# %%
data['Close'].resample('Q').mean()
# Out:
# Date
# 2013-06-30     115.162188
# 2013-09-30     111.291196
# 2013-12-31     502.657609
# 2014-03-31     700.586000
# 2014-06-30     520.929341
# 2014-09-30     534.055435
# 2014-12-31     357.075761
# 2015-03-31     251.209333
# 2015-06-30     236.858022
# 2015-09-30     254.859891
# 2015-12-31     346.037065
# 2016-03-31     410.728571
# 2016-06-30     512.492747
# 2016-09-30     615.702283
# 2016-12-31     732.721413
# 2017-03-31    1034.707444
# 2017-06-30    1912.552198
# 2017-09-30    2519.418387
# Freq: Q-DEC, Name: Close, dtype: float64

# %%
data['Close'].resample('Q').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Monthly Mean

# %%
data['Close'].resample('M').mean()
# Out:
# Date
# 2013-04-30     139.250000
# 2013-05-31     119.993226
# 2013-06-30     107.761333
# 2013-07-31      90.512258
# 2013-08-31     113.905161
# 2013-09-30     130.061667
# 2013-10-31     158.311935
# 2013-11-30     550.420667
# 2013-12-31     800.780968
# 2014-01-31     844.168387
# 2014-02-28     661.618214
# 2014-03-31     592.200323
# 2014-04-30     461.362000
# 2014-05-31     486.651290
# 2014-06-30     615.917333
# 2014-07-31     618.025484
# 2014-08-31     536.087742
# 2014-09-30     445.186333
# 2014-10-31     364.150000
# 2014-11-30     366.100000
# 2014-12-31     341.268387
# 2015-01-31     248.782581
# 2015-02-28     234.153571
# 2015-03-31     269.041290
# 2015-04-30     235.491667
# 2015-05-31     236.996774
# 2015-06-30     238.081000
# 2015-07-31     279.563871
# 2015-08-31     250.734516
# 2015-09-30     233.595333
# 2015-10-31     264.855161
# 2015-11-30     348.883333
# 2015-12-31     424.464516
# 2016-01-31     410.844516
# 2016-02-29     404.408276
# ...

# %%
data['Close'].resample('M').mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# Analysing Daily Change in Closing Price of Stocks

# %%
data['Close']
# Out:
# Date
# 2013-04-28     134.21
# 2013-04-29     144.54
# 2013-04-30     139.00
# 2013-05-01     116.99
# 2013-05-02     105.21
#                ...
# 2017-07-27    2671.78
# 2017-07-28    2809.01
# 2017-07-29    2726.45
# 2017-07-30    2757.18
# 2017-07-31    2875.34
# Name: Close, Length: 1556, dtype: float64

# %%
data['Close'].pct_change()
# Out:
# Date
# 2013-04-28         NaN
# 2013-04-29    0.076969
# 2013-04-30   -0.038328
# 2013-05-01   -0.158345
# 2013-05-02   -0.100692
#                 ...
# 2017-07-27    0.056269
# 2017-07-28    0.051363
# 2017-07-29   -0.029391
# 2017-07-30    0.011271
# 2017-07-31    0.042855
# Name: Close, Length: 1556, dtype: float64

# %%
data['Close'].pct_change()*100
# Out:
# Date
# 2013-04-28          NaN
# 2013-04-29     7.696893
# 2013-04-30    -3.832849
# 2013-05-01   -15.834532
# 2013-05-02   -10.069237
#                 ...
# 2017-07-27     5.626915
# 2017-07-28     5.136276
# 2017-07-29    -2.939114
# 2017-07-30     1.127107
# 2017-07-31     4.285538
# Name: Close, Length: 1556, dtype: float64

# %%
data['Close_price_pct_change']=data['Close'].pct_change()*100

# %%
data['Close_price_pct_change']
# Out:
# Date
# 2013-04-28          NaN
# 2013-04-29     7.696893
# 2013-04-30    -3.832849
# 2013-05-01   -15.834532
# 2013-05-02   -10.069237
#                 ...
# 2017-07-27     5.626915
# 2017-07-28     5.136276
# 2017-07-29    -2.939114
# 2017-07-30     1.127107
# 2017-07-31     4.285538
# Name: Close_price_pct_change, Length: 1556, dtype: float64

# %%
data['Close_price_pct_change'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
import chart_studio.plotly as py
import plotly.graph_objs as go
import plotly.express as px
from plotly.offline import download_plotlyjs,init_notebook_mode, plot, iplot
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import cufflinks as cf

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
data['Close_price_pct_change']
# Out:
# Date
# 2013-04-28          NaN
# 2013-04-29     7.696893
# 2013-04-30    -3.832849
# 2013-05-01   -15.834532
# 2013-05-02   -10.069237
#                 ...
# 2017-07-27     5.626915
# 2017-07-28     5.136276
# 2017-07-29    -2.939114
# 2017-07-30     1.127107
# 2017-07-31     4.285538
# Name: Close_price_pct_change, Length: 1556, dtype: float64

# %%
data['Close_price_pct_change'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
type(data['Close_price_pct_change'])
# Out:
# pandas.core.series.Series

# %%
data['Close_price_pct_change'].iplot()
# Out:
# <div>                            <div id="6504c940-f88c-42d5-82be-dbf33953f4b5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
